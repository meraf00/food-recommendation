# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

import preprocessing

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler

import pickle

# %%
user_health = preprocessing.load_users_health()
food_pref = preprocessing.load_food_pref_dataset()

# %%
user_health.head()
# Out:
#        seqn  weight  height   bmi  upper_leg_length  upper_arm_length
# 0  109264.0    42.2   154.7  17.6              36.3              33.8  \
# 1  109266.0    97.1   160.2  37.8              40.8              34.7
# 2  109270.0    75.3   156.0  30.9              42.6              36.1
# 3  109271.0    98.8   182.3  29.7              40.1              42.0
# 4  109273.0    74.3   184.2  21.9              41.0              41.1
#
#    arm_circumference  waist_circumference  hip_circumference    systolic
# 0               22.7                 63.8          85.000000  108.000000  \
# 1               35.8                117.9         126.100000   99.000000
# 2               31.0                 91.4         105.696877  124.666667
# 3               38.2                120.4         108.200000  107.000000
# 4               30.2                 86.8          94.500000  113.666667
#
#    diastolic      pulse
# 0  67.000000  93.333333
# 1  54.333333  66.666667
# 2  73.333333  95.333333
# 3  67.000000  71.333333
# 4  67.333333  70.333333

# %%
food_pref.head()
# Out:
#      seqn intake_day_of_week name_of_eating_occasion
# 0  109263             Friday                  Dinner  \
# 1  112171           Saturday                  Dinner
# 2  112586           Saturday                   Lunch
# 3  112670             Sunday                  Dinner
# 4  112670             Sunday               Breakfast
#
#                                source_of_food location_of_food_home
# 0                 Store - grocery/supermarket                   Yes  \
# 1  Grown or caught by you or someone you know                   Yes
# 2                      From someone else/gift                   Yes
# 3                 Store - grocery/supermarket                   Yes
# 4                 Store - grocery/supermarket                   Yes
#
#    usda_food_code   grams  energy_kcal  protein_gm  carbohydrate_gm  ...
# 0        28320300  199.50        114.0       12.11             5.07  ...  \
# 1        28320300  299.25        172.0       18.08             8.32  ...
# 2        28320300  199.51        114.0       12.11             5.07  ...
# 3        28320300  128.25         74.0        7.75             3.56  ...
# 4        28320300  171.00         98.0       10.33             4.75  ...
#
#    pfa_eicosadienoic_gm  pfa_eicosatrienoic_gm  pfa_docosapentaenoic_gm
# 0                 0.012           5.397605e-79             5.397605e-79  \
# 1                 0.018           5.397605e-79             5.397605e-79
# 2                 0.012           5.397605e-79             5.397605e-79
# 3                 0.008           5.397605e-79             5.397605e-79
# 4                 0.010           5.397605e-79             5.397605e-79
#
#    pfa_docosahexaenoic_gm  Food code
# 0            5.397605e-79   28320300  \
# 1            5.397605e-79   28320300
# 2            5.397605e-79   28320300
# 3            5.397605e-79   28320300
# 4            5.397605e-79   28320300
#
#                                Main food description  WWEIA Category number
# 0  Pork with vegetable excluding carrots, broccol...                   3802  \
# 1  Pork with vegetable excluding carrots, broccol...                   3802
# 2  Pork with vegetable excluding carrots, broccol...                   3802
# 3  Pork with vegetable excluding carrots, broccol...                   3802
# 4  Pork with vegetable excluding carrots, broccol...                   3802
#
#    WWEIA Category description  Start date   End date
# 0                       Soups  2019-01-01 2020-12-31
# 1                       Soups  2019-01-01 2020-12-31
# 2                       Soups  2019-01-01 2020-12-31
# 3                       Soups  2019-01-01 2020-12-31
# 4                       Soups  2019-01-01 2020-12-31
#
# [5 rows x 78 columns]

# %%
def convert_to_rating(series):                
    count = series.value_counts()

    series = series.apply(lambda x: count[x])

    max_ = count.max()
    min_ = count.min()                 
        
    return (series + 1 - min_) / (max_ - min_ + 1)

# %%
df = pd.DataFrame(food_pref)
df['rating'] = food_pref.groupby('seqn')['usda_food_code'].transform(convert_to_rating)
rating_df = df[['seqn', 'usda_food_code', 'rating']]
rating_df.head()
# Out:
#      seqn  usda_food_code  rating
# 0  109263        28320300     0.5
# 1  112171        28320300     1.0
# 2  112586        28320300     1.0
# 3  112670        28320300     1.0
# 4  112670        28320300     1.0

# %%
food_feature_columns = ["grams",
        "energy_kcal",
        "protein_gm",
        "carbohydrate_gm",
        "total_sugar_gm",
        "dietary_fiber_gm",
        "total_fat_gm",
        "total_saturated_fatty_acids_gm",
        "total_monounsaturated_fatty_acids_gm",
        "total_polyunsaturated_fatty_acids_gm",
        "cholesterol_mg",
        "vitamin_e_mg",
        "added_alpha_tocopherol_mg",
        "retinol_mcg",
        "vitamin_a_rae_mcg",
        "alpha_carotene_mcg",
        "beta_carotene_mcg",
        "beta_cryptoxanthin_mcg",
        "lycopene_mcg",
        "lutein_zeaxanthin_mcg",
        "thiamin_mg",
        "riboflavin_mg",
        "niacin_mg",
        "vitamin_b6_mg",
        "total_folate_mcg",
        "folic_acid_mcg",
        "food_folate_mcg",
        "dietary_folate_equivalents_mcg",
        "total_choline_mg",
        "vitamin_b12_mcg",
        "added_vitamin_b12_mcg",
        "vitamin_c_mg",
        "vitamin_d_d2_d3_mcg",
        "vitamin_k_mcg",
        "calcium_mg",
        "phosphorus_mg",
        "magnesium_mg",
        "iron_mg",
        "zinc_mg",
        "copper_mg",
        "sodium_mcg",
        "potassium_mg",
        "selenium_mcg",
        "caffeine_mg",
        "theobromine_mg",
        "alcohol_gm",
        "moisture_gm",
        "sfa_butanoic_gm",
        "sfa_hexanoic_gm",
        "sfa_octanoic_gm",
        "sfa_decanoic_gm",
        "sfa_dodecanoic_gm",
        "sfa_tetradecanoic_gm",
        "sfa_hexadecanoic_gm",
        "sfa_octadecanoic_gm",
        "mfa_hexadecenoic_gm",
        "mfa_octadecenoic_gm",
        "mfa_eicosenoic_gm",
        "mfa_docosenoic_gm",
        "pfa_octadecadienoic_gm",
        "pfa_octadecatrienoic_gm",
        "pfa_octadecatetraenoic_gm",
        "pfa_eicosadienoic_gm",
        "pfa_eicosatrienoic_gm",
        "pfa_docosapentaenoic_gm",
        "pfa_docosahexaenoic_gm",]

# %%
df_food_rating = pd.DataFrame()
df_food_rating['seqn'] = rating_df['seqn']
df_food_rating['usda_food_code'] = rating_df['usda_food_code']
df_food_rating['rating'] = rating_df['rating'].astype(float)
df_food_rating[food_feature_columns] = food_pref[food_feature_columns]

# %%
day_le = LabelEncoder()
day = day_le.fit_transform(food_pref['intake_day_of_week'].values)

occation_le = LabelEncoder()
occation = occation_le.fit_transform(food_pref['name_of_eating_occasion'].values.reshape(-1, 1))       

source_le = OneHotEncoder(sparse=False)
source = source_le.fit_transform(food_pref['source_of_food'].values.reshape(-1, 1)) 

scaler = StandardScaler()

df = df_food_rating[["seqn", "usda_food_code", "rating"] + food_feature_columns]
df[food_feature_columns] = scaler.fit_transform(df_food_rating[food_feature_columns])
# Out:
# c:\Users\L\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\L\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
with open('day_encoder.pickle', 'wb') as f:
    pickle.dump(day_le, f)

with open('occation_encoder.pickle', 'wb') as f:
    pickle.dump(occation_le, f)

with open('source_encoder.pickle', 'wb') as f:
    pickle.dump(source_le, f)

with open('scaler.pickle', 'wb') as f:
    pickle.dump(scaler, f)

# %%
df.head()
# Out:
#      seqn  usda_food_code  rating     grams  energy_kcal  protein_gm
# 0  109263        28320300     0.5  0.085152    -0.143642    0.734353  \
# 1  112171        28320300     1.0  0.410993     0.165342    1.349121
# 2  112586        28320300     1.0  0.085185    -0.143642    0.734353
# 3  112670        28320300     1.0 -0.147592    -0.356734    0.285376
# 4  112670        28320300     1.0 -0.007945    -0.228879    0.551055
#
#    carbohydrate_gm  total_sugar_gm  dietary_fiber_gm  total_fat_gm  ...
# 0        -0.498431       -0.363180          0.266717     -0.072528  ...  \
# 1        -0.363248       -0.280396          0.707407      0.173553  ...
# 2        -0.498431       -0.363180          0.266717     -0.072528  ...
# 3        -0.561238       -0.408215          0.021889     -0.248869  ...
# 4        -0.511741       -0.376426          0.168786     -0.143264  ...
#
#    mfa_octadecenoic_gm  mfa_eicosenoic_gm  mfa_docosenoic_gm
# 0             0.038240           0.215254          -0.080236  \
# 1             0.329943           0.397034           0.035354
# 2             0.038240           0.215254          -0.080236
# 3            -0.154416          -0.011972          -0.041706
# 4            -0.033326           0.078918          -0.003176
#
#    pfa_octadecadienoic_gm  pfa_octadecatrienoic_gm  pfa_octadecatetraenoic_gm
# 0               -0.135023                -0.103540                   -0.07538  \
# 1                0.025099                 0.078515                   -0.07538
# 2               -0.135023                -0.103540                   -0.07538
# 3               -0.248095                -0.188066                   -0.07538
# 4               -0.179796                -0.123046                   -0.07538
#
#    pfa_eicosadienoic_gm  pfa_eicosatrienoic_gm  pfa_docosapentaenoic_gm
# 0              0.094681              -0.065156                -0.125102  \
# 1              0.301119              -0.065156                -0.125102
# 2              0.094681              -0.065156                -0.125102
# 3             -0.042945              -0.065156                -0.125102
# 4              0.025868              -0.065156                -0.125102
#
#    pfa_docosahexaenoic_gm
# 0               -0.077358
# 1               -0.077358
# 2               -0.077358
# 3               -0.077358
# 4               -0.077358
#
# [5 rows x 69 columns]

# %%
user_idx_map = {u: e for e, u in enumerate(df.seqn.unique())}
food_idx_map = {i: e for e, i in enumerate(df.usda_food_code.unique())}

# %%
with open('user_idx_map.pickle', 'wb') as f:
    pickle.dump(user_idx_map, f)

with open('food_idx_map.pickle', 'wb') as f:
    pickle.dump(food_idx_map, f)

# %%
df["user_idx"] = df["seqn"].apply(lambda x: user_idx_map[x])
df["food_idx"] = df["usda_food_code"].apply(lambda x: food_idx_map[x])

# %%
print(df["user_idx"].max())
print(df["food_idx"].max())
# Out:
# 12557
# 4511

# %%
df.head()
# Out:
#      seqn  usda_food_code  rating     grams  energy_kcal  protein_gm
# 0  109263        28320300     0.5  0.085152    -0.143642    0.734353  \
# 1  112171        28320300     1.0  0.410993     0.165342    1.349121
# 2  112586        28320300     1.0  0.085185    -0.143642    0.734353
# 3  112670        28320300     1.0 -0.147592    -0.356734    0.285376
# 4  112670        28320300     1.0 -0.007945    -0.228879    0.551055
#
#    carbohydrate_gm  total_sugar_gm  dietary_fiber_gm  total_fat_gm  ...
# 0        -0.498431       -0.363180          0.266717     -0.072528  ...  \
# 1        -0.363248       -0.280396          0.707407      0.173553  ...
# 2        -0.498431       -0.363180          0.266717     -0.072528  ...
# 3        -0.561238       -0.408215          0.021889     -0.248869  ...
# 4        -0.511741       -0.376426          0.168786     -0.143264  ...
#
#    mfa_docosenoic_gm  pfa_octadecadienoic_gm  pfa_octadecatrienoic_gm
# 0          -0.080236               -0.135023                -0.103540  \
# 1           0.035354                0.025099                 0.078515
# 2          -0.080236               -0.135023                -0.103540
# 3          -0.041706               -0.248095                -0.188066
# 4          -0.003176               -0.179796                -0.123046
#
#    pfa_octadecatetraenoic_gm  pfa_eicosadienoic_gm  pfa_eicosatrienoic_gm
# 0                   -0.07538              0.094681              -0.065156  \
# 1                   -0.07538              0.301119              -0.065156
# 2                   -0.07538              0.094681              -0.065156
# 3                   -0.07538             -0.042945              -0.065156
# 4                   -0.07538              0.025868              -0.065156
#
#    pfa_docosapentaenoic_gm  pfa_docosahexaenoic_gm  user_idx  food_idx
# 0                -0.125102               -0.077358         0         0
# 1                -0.125102               -0.077358         1         0
# 2                -0.125102               -0.077358         2         0
# 3                -0.125102               -0.077358         3         0
# 4                -0.125102               -0.077358         3         0
#
# [5 rows x 71 columns]

# %%
from sklearn.model_selection import train_test_split

df_rating_train, df_rating_test = train_test_split(df, test_size=0.1, random_state=42)

# %%
X_train = [df_rating_train['user_idx'].values, df_rating_train['food_idx'].values, df_rating_train.drop(['seqn', 'usda_food_code', 'rating', 'user_idx', 'food_idx'], axis=1)]
y_train = df_rating_train['rating'].values

X_test = [df_rating_test['user_idx'].values, df_rating_test['food_idx'].values, df_rating_test.drop(['seqn', 'usda_food_code', 'rating', 'user_idx', 'food_idx'], axis=1)]
y_test = df_rating_test['rating'].values

# %%
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
tf.compat.v1.enable_eager_execution()
import tensorflow.keras as keras
from tensorflow.keras.layers import Input, Embedding, Dot, Concatenate, Add, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
# Out:
# WARNING:tensorflow:From c:\Users\L\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\compat\v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
def create_model(n_users, user_embed_size_dot, user_embed_size_concat, n_items, item_embed_size, item_feature_len, regularization=1e-4):
     
    item_features = Input(shape=(item_feature_len, ), name="item_features")
    user_inp = Input(shape=(1, ), dtype='int32', name="user_embed")
    user_embed = Embedding(n_users, 
                           user_embed_size_dot, 
                           name='user_embed_mat',
                           embeddings_initializer="glorot_uniform", 
                           embeddings_regularizer=keras.regularizers.l2(regularization))(user_inp)
    user_embed_bias = Embedding(n_users, 
                                1, 
                                name='user_embed_bias_mat',
                                embeddings_initializer="glorot_uniform")(user_inp)
    user_embed_c = Embedding(n_users, 
                             user_embed_size_concat, 
                             name='user_embed_c_mat',
                             embeddings_initializer="glorot_uniform", 
                             embeddings_regularizer=keras.regularizers.l2(regularization))(user_inp)
    
    item_inp = Input(shape=(1, ), dtype='int32', name="item_embed")
    item_embed = Embedding(n_items, 
                           item_embed_size, 
                           name='item_embed_mat',
                           embeddings_initializer="glorot_uniform", 
                           embeddings_regularizer=keras.regularizers.l2(regularization))(item_inp)
    item_embed_bias = Embedding(n_items, 
                                1, 
                                name='item_embed_bias_mat',
                                embeddings_initializer="glorot_uniform")(item_inp)
    
    user_item_dot = Dot(axes=2, name='user_item_dot')([user_embed, item_embed])
    
    user_item_dot = Add()([user_item_dot, user_embed_bias, item_embed_bias])
    user_item_dot = Flatten()(user_item_dot)
    user_embed_c = Flatten()(user_embed_c)
    
    user_item_concat = Concatenate(axis=1)([user_embed_c, item_features])
    
    hidden1 = Dense(8, activation="relu")(user_item_concat)
    hidden1 = BatchNormalization()(hidden1)
    hidden1 = Dropout(0.2)(hidden1)
    
    dot_hidden1_concat = Concatenate(axis=1)([hidden1, user_item_dot])
    
    output = Dense(1, activation="relu")(dot_hidden1_concat)
    
    model = Model([user_inp, item_inp, item_features], output)
    
    return model

# %%
N_USERS = df.user_idx.max() + 1
N_ITEMS = df.food_idx.max() + 1
USER_EMBEDDING_SIZE_DOT = 20
USER_EMBEDDING_SIZE_CONCAT = 20
ITEM_EMBEDDING_SIZE = 20
ITEM_FEATURE_LEN = len(food_feature_columns)

model = create_model(N_USERS, USER_EMBEDDING_SIZE_DOT, USER_EMBEDDING_SIZE_CONCAT, N_ITEMS, ITEM_EMBEDDING_SIZE, ITEM_FEATURE_LEN)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  user_embed (InputLayer)        [(None, 1)]          0           []
#
#  user_embed_c_mat (Embedding)   (None, 1, 20)        251160      ['user_embed[0][0]']
#
#  flatten_3 (Flatten)            (None, 20)           0           ['user_embed_c_mat[0][0]']
#
#  item_features (InputLayer)     [(None, 66)]         0           []
#
#  item_embed (InputLayer)        [(None, 1)]          0           []
#
#  concatenate_2 (Concatenate)    (None, 86)           0           ['flatten_3[0][0]',
#                                                                   'item_features[0][0]']
#
#  user_embed_mat (Embedding)     (None, 1, 20)        251160      ['user_embed[0][0]']
#
#  item_embed_mat (Embedding)     (None, 1, 20)        90240       ['item_embed[0][0]']
#
#  dense_2 (Dense)                (None, 8)            696         ['concatenate_2[0][0]']
#
#  user_item_dot (Dot)            (None, 1, 1)         0           ['user_embed_mat[0][0]',
#                                                                   'item_embed_mat[0][0]']
#
#  user_embed_bias_mat (Embedding  (None, 1, 1)        12558       ['user_embed[0][0]']
#  )
#
#  item_embed_bias_mat (Embedding  (None, 1, 1)        4512        ['item_embed[0][0]']
#  )
#
#  batch_normalization_1 (BatchNo  (None, 8)           32          ['dense_2[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 1, 1)         0           ['user_item_dot[0][0]',
#                                                                   'user_embed_bias_mat[0][0]',
#                                                                   'item_embed_bias_mat[0][0]']
#
#  dropout_1 (Dropout)            (None, 8)            0           ['batch_normalization_1[0][0]']
#
#  flatten_2 (Flatten)            (None, 1)            0           ['add_1[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 9)            0           ['dropout_1[0][0]',
#                                                                   'flatten_2[0][0]']
#
#  dense_3 (Dense)                (None, 1)            10          ['concatenate_3[0][0]']
#
# ==================================================================================================
# Total params: 610,368
# Trainable params: 610,352
# Non-trainable params: 16
# __________________________________________________________________________________________________

# %%
model.compile(Adam(1e-3), loss="mse", metrics=["mae"])

# %%
# callbacks defined

# learning rate schedule
def step_decay(epoch):
    initial_lrate = 0.001
    drop = 0.5
    epochs_drop = 5
    lrate = initial_lrate * (drop**((1 + epoch)/epochs_drop))
    return lrate

lrate_scheduler = LearningRateScheduler(step_decay)
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
model_chkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

# model fitting
history = model.fit(X_train, y_train, batch_size=32, epochs=50, validation_split=0.1, callbacks=[early_stop, model_chkpoint, lrate_scheduler])
# Out:
# Epoch 1/50
# 4193/4195 [============================>.] - ETA: 0s - loss: 0.1164 - mae: 0.2517
# Epoch 1: val_loss improved from inf to 0.04687, saving model to best_model.h5
# 4195/4195 [==============================] - 52s 12ms/step - loss: 0.1164 - mae: 0.2516 - val_loss: 0.0469 - val_mae: 0.1597 - lr: 8.7055e-04
# Epoch 2/50
# 4190/4195 [============================>.] - ETA: 0s - loss: 0.0373 - mae: 0.1382
# Epoch 2: val_loss improved from 0.04687 to 0.03712, saving model to best_model.h5
# 4195/4195 [==============================] - 37s 9ms/step - loss: 0.0373 - mae: 0.1382 - val_loss: 0.0371 - val_mae: 0.1360 - lr: 7.5786e-04
# Epoch 3/50
# 4190/4195 [============================>.] - ETA: 0s - loss: 0.0318 - mae: 0.1230
# Epoch 3: val_loss improved from 0.03712 to 0.03517, saving model to best_model.h5
# 4195/4195 [==============================] - 36s 9ms/step - loss: 0.0318 - mae: 0.1230 - val_loss: 0.0352 - val_mae: 0.1281 - lr: 6.5975e-04
# Epoch 4/50
# 4189/4195 [============================>.] - ETA: 0s - loss: 0.0302 - mae: 0.1175
# Epoch 4: val_loss improved from 0.03517 to 0.03411, saving model to best_model.h5
# 4195/4195 [==============================] - 36s 9ms/step - loss: 0.0302 - mae: 0.1175 - val_loss: 0.0341 - val_mae: 0.1272 - lr: 5.7435e-04
# Epoch 5/50
# 4193/4195 [============================>.] - ETA: 0s - loss: 0.0292 - mae: 0.1144
# Epoch 5: val_loss improved from 0.03411 to 0.03391, saving model to best_model.h5
# 4195/4195 [==============================] - 37s 9ms/step - loss: 0.0292 - mae: 0.1144 - val_loss: 0.0339 - val_mae: 0.1248 - lr: 5.0000e-04
# Epoch 6/50
# 4192/4195 [============================>.] - ETA: 0s - loss: 0.0285 - mae: 0.1120
# Epoch 6: val_loss improved from 0.03391 to 0.03349, saving model to best_model.h5
# 4195/4195 [==============================] - 40s 10ms/step - loss: 0.0286 - mae: 0.1120 - val_loss: 0.0335 - val_mae: 0.1229 - lr: 4.3528e-04
# Epoch 7/50
# 4192/4195 [============================>.] - ETA: 0s - loss: 0.0280 - mae: 0.1103
# Epoch 7: val_loss improved from 0.03349 to 0.03336, saving model to best_model.h5
# 4195/4195 [==============================] - 43s 10ms/step - loss: 0.0280 - mae: 0.1102 - val_loss: 0.0334 - val_mae: 0.1224 - lr: 3.7893e-04
# Epoch 8/50
# 4193/4195 [============================>.] - ETA: 0s - loss: 0.0276 - mae: 0.1089
# Epoch 8: val_loss improved from 0.03336 to 0.03321, saving model to best_model.h5
# 4195/4195 [==============================] - 43s 10ms/step - loss: 0.0276 - mae: 0.1089 - val_loss: 0.0332 - val_mae: 0.1215 - lr: 3.2988e-04
# Epoch 9/50
# 4191/4195 [============================>.] - ETA: 0s - loss: 0.0272 - mae: 0.1076
# Epoch 9: val_loss improved from 0.03321 to 0.03310, saving model to best_model.h5
# 4195/4195 [==============================] - 43s 10ms/step - loss: 0.0272 - mae: 0.1076 - val_loss: 0.0331 - val_mae: 0.1214 - lr: 2.8717e-04
# Epoch 10/50
# 4195/4195 [==============================] - ETA: 0s - loss: 0.0270 - mae: 0.1066
# Epoch 10: val_loss improved from 0.03310 to 0.03307, saving model to best_model.h5
# 4195/4195 [==============================] - 43s 10ms/step - loss: 0.0270 - mae: 0.1066 - val_loss: 0.0331 - val_mae: 0.1208 - lr: 2.5000e-04
# Epoch 11/50
# 4194/4195 [============================>.] - ETA: 0s - loss: 0.0267 - mae: 0.1057
# Epoch 11: val_loss improved from 0.03307 to 0.03303, saving model to best_model.h5
# 4195/4195 [==============================] - 44s 10ms/step - loss: 0.0267 - mae: 0.1057 - val_loss: 0.0330 - val_mae: 0.1205 - lr: 2.1764e-04
# Epoch 12/50
# 4195/4195 [==============================] - ETA: 0s - loss: 0.0265 - mae: 0.1051
# Epoch 12: val_loss improved from 0.03303 to 0.03294, saving model to best_model.h5
# 4195/4195 [==============================] - 44s 10ms/step - loss: 0.0265 - mae: 0.1051 - val_loss: 0.0329 - val_mae: 0.1199 - lr: 1.8946e-04
# Epoch 13/50
# 4193/4195 [============================>.] - ETA: 0s - loss: 0.0262 - mae: 0.1040
# Epoch 13: val_loss improved from 0.03294 to 0.03286, saving model to best_model.h5
# 4195/4195 [==============================] - 45s 11ms/step - loss: 0.0262 - mae: 0.1040 - val_loss: 0.0329 - val_mae: 0.1199 - lr: 1.6494e-04
# Epoch 14/50
# 4192/4195 [============================>.] - ETA: 0s - loss: 0.0259 - mae: 0.1034
# Epoch 14: val_loss improved from 0.03286 to 0.03278, saving model to best_model.h5
# 4195/4195 [==============================] - 46s 11ms/step - loss: 0.0260 - mae: 0.1035 - val_loss: 0.0328 - val_mae: 0.1191 - lr: 1.4359e-04
# Epoch 15/50
# 4193/4195 [============================>.] - ETA: 0s - loss: 0.0257 - mae: 0.1025
# Epoch 15: val_loss improved from 0.03278 to 0.03272, saving model to best_model.h5
# 4195/4195 [==============================] - 45s 11ms/step - loss: 0.0257 - mae: 0.1025 - val_loss: 0.0327 - val_mae: 0.1189 - lr: 1.2500e-04
# Epoch 16/50
# 4193/4195 [============================>.] - ETA: 0s - loss: 0.0254 - mae: 0.1019
# Epoch 16: val_loss improved from 0.03272 to 0.03260, saving model to best_model.h5
# 4195/4195 [==============================] - 44s 11ms/step - loss: 0.0254 - mae: 0.1020 - val_loss: 0.0326 - val_mae: 0.1185 - lr: 1.0882e-04
# Epoch 17/50
# 4191/4195 [============================>.] - ETA: 0s - loss: 0.0251 - mae: 0.1011
# Epoch 17: val_loss improved from 0.03260 to 0.03253, saving model to best_model.h5
# 4195/4195 [==============================] - 45s 11ms/step - loss: 0.0251 - mae: 0.1011 - val_loss: 0.0325 - val_mae: 0.1182 - lr: 9.4732e-05
# Epoch 18/50
# 4195/4195 [==============================] - ETA: 0s - loss: 0.0248 - mae: 0.1004
# Epoch 18: val_loss improved from 0.03253 to 0.03240, saving model to best_model.h5
# 4195/4195 [==============================] - 44s 11ms/step - loss: 0.0248 - mae: 0.1004 - val_loss: 0.0324 - val_mae: 0.1175 - lr: 8.2469e-05
# Epoch 19/50
# 4192/4195 [============================>.] - ETA: 0s - loss: 0.0246 - mae: 0.0998
# Epoch 19: val_loss improved from 0.03240 to 0.03235, saving model to best_model.h5
# 4195/4195 [==============================] - 46s 11ms/step - loss: 0.0246 - mae: 0.0998 - val_loss: 0.0323 - val_mae: 0.1173 - lr: 7.1794e-05
# Epoch 20/50
# 4192/4195 [============================>.] - ETA: 0s - loss: 0.0244 - mae: 0.0994
# Epoch 20: val_loss improved from 0.03235 to 0.03228, saving model to best_model.h5
# 4195/4195 [==============================] - 45s 11ms/step - loss: 0.0243 - mae: 0.0994 - val_loss: 0.0323 - val_mae: 0.1169 - lr: 6.2500e-05
# Epoch 21/50
# 4195/4195 [==============================] - ETA: 0s - loss: 0.0241 - mae: 0.0988
# Epoch 21: val_loss improved from 0.03228 to 0.03223, saving model to best_model.h5
# 4195/4195 [==============================] - 45s 11ms/step - loss: 0.0241 - mae: 0.0988 - val_loss: 0.0322 - val_mae: 0.1166 - lr: 5.4409e-05
# Epoch 22/50
# 4194/4195 [============================>.] - ETA: 0s - loss: 0.0238 - mae: 0.0982
# Epoch 22: val_loss improved from 0.03223 to 0.03221, saving model to best_model.h5
# 4195/4195 [==============================] - 45s 11ms/step - loss: 0.0238 - mae: 0.0982 - val_loss: 0.0322 - val_mae: 0.1167 - lr: 4.7366e-05
# Epoch 23/50
# 4195/4195 [==============================] - ETA: 0s - loss: 0.0237 - mae: 0.0977
# Epoch 23: val_loss improved from 0.03221 to 0.03208, saving model to best_model.h5
# 4195/4195 [==============================] - 44s 11ms/step - loss: 0.0237 - mae: 0.0977 - val_loss: 0.0321 - val_mae: 0.1163 - lr: 4.1235e-05
# Epoch 24/50
# 4194/4195 [============================>.] - ETA: 0s - loss: 0.0235 - mae: 0.0974
# Epoch 24: val_loss did not improve from 0.03208
# 4195/4195 [==============================] - 45s 11ms/step - loss: 0.0235 - mae: 0.0974 - val_loss: 0.0321 - val_mae: 0.1164 - lr: 3.5897e-05
# Epoch 25/50
# 4194/4195 [============================>.] - ETA: 0s - loss: 0.0233 - mae: 0.0969
# Epoch 25: val_loss improved from 0.03208 to 0.03204, saving model to best_model.h5
# 4195/4195 [==============================] - 45s 11ms/step - loss: 0.0233 - mae: 0.0969 - val_loss: 0.0320 - val_mae: 0.1158 - lr: 3.1250e-05
# Epoch 26/50
# 4193/4195 [============================>.] - ETA: 0s - loss: 0.0231 - mae: 0.0964
# Epoch 26: val_loss did not improve from 0.03204
# 4195/4195 [==============================] - 47s 11ms/step - loss: 0.0231 - mae: 0.0964 - val_loss: 0.0321 - val_mae: 0.1163 - lr: 2.7205e-05
# Epoch 27/50
# 4191/4195 [============================>.] - ETA: 0s - loss: 0.0230 - mae: 0.0962
# Epoch 27: val_loss improved from 0.03204 to 0.03197, saving model to best_model.h5
# 4195/4195 [==============================] - 47s 11ms/step - loss: 0.0230 - mae: 0.0962 - val_loss: 0.0320 - val_mae: 0.1161 - lr: 2.3683e-05
# Epoch 28/50
# 4193/4195 [============================>.] - ETA: 0s - loss: 0.0228 - mae: 0.0959
# Epoch 28: val_loss did not improve from 0.03197
# 4195/4195 [==============================] - 45s 11ms/step - loss: 0.0228 - mae: 0.0959 - val_loss: 0.0321 - val_mae: 0.1159 - lr: 2.0617e-05
# Epoch 29/50
# 4191/4195 [============================>.] - ETA: 0s - loss: 0.0228 - mae: 0.0955
# Epoch 29: val_loss did not improve from 0.03197
# 4195/4195 [==============================] - 45s 11ms/step - loss: 0.0228 - mae: 0.0955 - val_loss: 0.0320 - val_mae: 0.1159 - lr: 1.7948e-05
# Epoch 30/50
# 4193/4195 [============================>.] - ETA: 0s - loss: 0.0227 - mae: 0.0954
# Epoch 30: val_loss did not improve from 0.03197
# 4195/4195 [==============================] - 45s 11ms/step - loss: 0.0227 - mae: 0.0954 - val_loss: 0.0320 - val_mae: 0.1158 - lr: 1.5625e-05
# Epoch 31/50
# 4193/4195 [============================>.] - ETA: 0s - loss: 0.0226 - mae: 0.0953
# Epoch 31: val_loss did not improve from 0.03197
# 4195/4195 [==============================] - 45s 11ms/step - loss: 0.0226 - mae: 0.0953 - val_loss: 0.0321 - val_mae: 0.1160 - lr: 1.3602e-05
# Epoch 32/50
# 4195/4195 [==============================] - ETA: 0s - loss: 0.0225 - mae: 0.0949
# Epoch 32: val_loss did not improve from 0.03197
# 4195/4195 [==============================] - 45s 11ms/step - loss: 0.0225 - mae: 0.0949 - val_loss: 0.0320 - val_mae: 0.1156 - lr: 1.1842e-05
# Epoch 32: early stopping

# %%
model.predict(X_test)
# Out:
# 518/518 [==============================] - 2s 4ms/step
# array([[0.99684525],
#        [0.5406385 ],
#        [0.48996627],
#        ...,
#        [0.44338906],
#        [0.5290402 ],
#        [0.6981675 ]], dtype=float32)

# %%
df_rating_test['prediction'] = [t[0] for t in model.predict(X_test)]
# Out:
# 518/518 [==============================] - 2s 3ms/step

# %%
df_rating_test[['rating', 'prediction']].head()
# Out:
#           rating  prediction
# 123563  1.000000    0.996845
# 13256   0.500000    0.540639
# 114342  0.500000    0.489966
# 152815  0.333333    0.374104
# 35      0.333333    0.376158

# %%
print("Test MAE: {}".format(sum(abs(df_rating_test["rating"] - df_rating_test["prediction"]))/len(df_rating_test)))
# Out:
# Test MAE: 0.11532597053637456

# %%
plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.plot(history.history['lr'])
plt.title('Training history')
plt.ylabel('value')
plt.xlabel('epoch')
plt.legend(['train mae', 'val mae', 'train loss', 'val loss', 'lr'], loc='upper left')
plt.show()
